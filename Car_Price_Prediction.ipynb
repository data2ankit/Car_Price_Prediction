# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#plt.style.use('dark_background')

# %% [markdown]
# Problem Statement
# find which features affect sale and resele of the cars.
# is the sale is related to resale or not

# %%
![image.png](attachment:cbd03ca9-1a05-4c38-b82c-3b7e88c12e78.png)

# %%
data=pd.read_csv(r"C:\Users\Sai\Downloads\car_done.csv")

# %%
data.info()   #gives me information about data that we call using pandas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Manufacturer            157 non-null    object
#  1   Model                   157 non-null    object
#  2   Sales_in_thousands      157 non-null    float64
#  3   four_year_resale_value  121 non-null    float64
#  4   Vehicle_type            157 non-null    object
#  5   Price_in_thousands      155 non-null    float64
#  6   Engine_size             156 non-null    float64
#  7   Horsepower              156 non-null    float64
#  8   Wheelbase               156 non-null    float64
#  9   Width                   156 non-null    float64
#  10  Length                  156 non-null    float64
#  11  Curb weight             155 non-null    float64
#  12  Fuel_capacity           156 non-null    float64
#  13  Fuel_efficiency         154 non-null    float64
# ...

# %%
data.isnull()
# Out:
#      Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 0           False  False               False                   False
# 1           False  False               False                   False
# 2           False  False               False                   False
# 3           False  False               False                   False
# 4           False  False               False                   False
# ..            ...    ...                 ...                     ...
# 152         False  False               False                    True
# 153         False  False               False                    True
# 154         False  False               False                    True
# 155         False  False               False                    True
# 156         False  False               False                    True
#
#      Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
print(data.head())
print(data.tail())
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb weight  Fuel_capacity  Fuel_efficiency
# ...

# %%
data.columns #column ko print karwane k liye
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'four_year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb weight', 'Fuel_capacity',
#        'Fuel_efficiency'],
#       dtype='object')

# %%
data.shape
# Out:
# (157, 14)

# %% [markdown]
# ## five pointer statstical summary non object data type quantative data

# %%
data.describe().T
# Out:
#                         count        mean        std      min       25%  \
# Sales_in_thousands      157.0   52.998076  68.029422    0.110   14.1140
# four_year_resale_value  121.0   18.072975  11.453384    5.160   11.2600
# Price_in_thousands      155.0   27.390755  14.351653    9.235   18.0175
# Engine_size             156.0    3.060897   1.044653    1.000    2.3000
# Horsepower              156.0  185.948718  56.700321   55.000  149.5000
# Wheelbase               156.0  107.487179   7.641303   92.600  103.0000
# Width                   156.0   71.150000   3.451872   62.600   68.4000
# Length                  156.0  187.343590  13.431754  149.400  177.5750
# Curb weight             155.0    3.378026   0.630502    1.895    2.9710
# Fuel_capacity           156.0   17.951923   3.887921   10.300   15.8000
# Fuel_efficiency         154.0   23.844156   4.282706   15.000   21.0000
#
#                             50%       75%      max
# Sales_in_thousands       29.450   67.9560  540.561
# ...

# %%
data.describe(percentiles=[.01,.02,.03,.5,.75,.90]).T   # T=transpose way to display
# Out:
#                         count        mean        std      min         1%  \
# Sales_in_thousands      157.0   52.998076  68.029422    0.110    0.93728
# four_year_resale_value  121.0   18.072975  11.453384    5.160    6.17300
# Price_in_thousands      155.0   27.390755  14.351653    9.235   10.23144
# Engine_size             156.0    3.060897   1.044653    1.000    1.55500
# Horsepower              156.0  185.948718  56.700321   55.000   96.40000
# Wheelbase               156.0  107.487179   7.641303   92.600   92.87500
# Width                   156.0   71.150000   3.451872   62.600   66.08500
# Length                  156.0  187.343590  13.431754  149.400  154.91500
# Curb weight             155.0    3.378026   0.630502    1.895    2.24540
# Fuel_capacity           156.0   17.951923   3.887921   10.300   11.90000
# Fuel_efficiency         154.0   23.844156   4.282706   15.000   15.00000
#
#                                2%         3%      50%       75%       90%  \
# ...

# %% [markdown]
# #Notes
# 1. Sales in thousands having 0.93 as 1%  and 540.5 for 100%
# 2. horspower 8 to 9 times increase form 1 to 100%
# 3. fuel almost doubled from 50% to 100%
# 4. width variation is not among all the company's rule for production.
# 5. engine size is mostly increased from 1  to 8 times means 80% engine size increased
# 6. length of the diffrence of 25%
# 7.
# 8.
# 9.
# 10.
# 11.

# %%
9.the data variance says that there is 3 times variance in fuel efficiency.

# %%
data[data['Model'].duplicated()]
# Out:
#     Manufacturer Model  Sales_in_thousands  four_year_resale_value  \
# 114     Plymouth  Neon              32.734                    7.75
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 114    Passenger               12.64          2.0       132.0      105.0
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 114   74.4   174.4        2.559           12.5             29.0

# %%
data[data.duplicated(subset=['Model'])]
# Out:
#     Manufacturer Model  Sales_in_thousands  four_year_resale_value  \
# 114     Plymouth  Neon              32.734                    7.75
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 114    Passenger               12.64          2.0       132.0      105.0
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 114   74.4   174.4        2.559           12.5             29.0

# %%
features=['Manufacturer', 'Model', 'Sales_in_thousands', 'four_year_resale_value',
       'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
       'Wheelbase', 'Width', 'Length', 'Curb weight', 'Fuel_capacity',
       'Fuel_efficiency']

for i in features:
    a=data[i].duplicated().value_counts()
    print(a)
# Out:
# Manufacturer
# True     127
# False     30
# Name: count, dtype: int64
# Model
# False    156
# True       1
# Name: count, dtype: int64
# Sales_in_thousands
# False    157
# Name: count, dtype: int64
# four_year_resale_value
# False    118
# True      39
# Name: count, dtype: int64
# Vehicle_type
# True     155
# False      2
# Name: count, dtype: int64
# Price_in_thousands
# False    153
# True       4
# Name: count, dtype: int64
# Engine_size
# True     125
# False     32
# Name: count, dtype: int64
# Horsepower
# True     90
# False    67
# Name: count, dtype: int64
# Wheelbase
# False    89
# True     68
# Name: count, dtype: int64
# Width
# False    79
# True     78
# Name: count, dtype: int64
# Length
# False    128
# True      29
# Name: count, dtype: int64
# Curb weight
# False    148
# True       9
# Name: count, dtype: int64
# Fuel_capacity
# True     101
# False     56
# Name: count, dtype: int64
# Fuel_efficiency
# True     136
# False     21
# Name: count, dtype: int64

# %%
#there is no need of treatment of duplicated values

# %%
data.isna().sum()
# Out:
# Manufacturer               0
# Model                      0
# Sales_in_thousands         0
# four_year_resale_value    36
# Vehicle_type               0
# Price_in_thousands         2
# Engine_size                1
# Horsepower                 1
# Wheelbase                  1
# Width                      1
# Length                     1
# Curb weight                2
# Fuel_capacity              1
# Fuel_efficiency            3
# dtype: int64

# %%
data[data==0].sum()
# Out:
# Manufacturer                0
# Model                       0
# Sales_in_thousands        0.0
# four_year_resale_value    0.0
# Vehicle_type                0
# Price_in_thousands        0.0
# Engine_size               0.0
# Horsepower                0.0
# Wheelbase                 0.0
# Width                     0.0
# Length                    0.0
# Curb weight               0.0
# Fuel_capacity             0.0
# Fuel_efficiency           0.0
# dtype: object

# %% [markdown]
# ### Categorical columns

# %%
data.dtypes[data.dtypes=='object']
# Out:
# Manufacturer    object
# Model           object
# Vehicle_type    object
# dtype: object

# %%
data["Manufacturer"].nunique()     #n= number of unique value
# Out:
# 30

# %%
data["Manufacturer"].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti',
#        'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mitsubishi', 'Mercury',
#        'Mercedes-B', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac',
#        'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
#we have 30 diffrent brands

# %%
data["Manufacturer"].value_counts() #Har brand k kitne model hai
# Out:
# Manufacturer
# Dodge         11
# Ford          11
# Toyota         9
# Chevrolet      9
# Mercedes-B     9
# Mitsubishi     7
# Nissan         7
# Chrysler       7
# Volvo          6
# Oldsmobile     6
# Lexus          6
# Mercury        6
# Pontiac        6
# Volkswagen     6
# Saturn         5
# Cadillac       5
# Honda          5
# Plymouth       4
# Acura          4
# Buick          4
# Audi           3
# Jeep           3
# Porsche        3
# Hyundai        3
# BMW            3
# Lincoln        3
# Saab           2
# Subaru         2
# Jaguar         1
# Infiniti       1
# Name: count, dtype: int64

# %%
data["Manufacturer"].nunique()
# Out:
# 30

# %%
features=['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
       'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti',
       'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mitsubishi', 'Mercury',
       'Mercedes-B', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac',
       'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen',
       'Volvo']

# %%
data.groupby('Manufacturer')['Model'].nunique()
# Out:
# Manufacturer
# Acura          4
# Audi           3
# BMW            3
# Buick          4
# Cadillac       5
# Chevrolet      9
# Chrysler       7
# Dodge         11
# Ford          11
# Honda          5
# Hyundai        3
# Infiniti       1
# Jaguar         1
# Jeep           3
# Lexus          6
# Lincoln        3
# Mercedes-B     9
# Mercury        6
# Mitsubishi     7
# Nissan         7
# Oldsmobile     6
# Plymouth       4
# Pontiac        6
# Porsche        3
# Saab           2
# Saturn         5
# Subaru         2
# Toyota         9
# Volkswagen     6
# Volvo          6
# Name: Model, dtype: int64

# %%
data["Manufacturer"].value_counts(normalize=True)  #gives values in percentage
# Out:
# Manufacturer
# Dodge         0.070064
# Ford          0.070064
# Toyota        0.057325
# Chevrolet     0.057325
# Mercedes-B    0.057325
# Mitsubishi    0.044586
# Nissan        0.044586
# Chrysler      0.044586
# Volvo         0.038217
# Oldsmobile    0.038217
# Lexus         0.038217
# Mercury       0.038217
# Pontiac       0.038217
# Volkswagen    0.038217
# Saturn        0.031847
# Cadillac      0.031847
# Honda         0.031847
# Plymouth      0.025478
# Acura         0.025478
# Buick         0.025478
# Audi          0.019108
# Jeep          0.019108
# Porsche       0.019108
# Hyundai       0.019108
# BMW           0.019108
# Lincoln       0.019108
# Saab          0.012739
# Subaru        0.012739
# Jaguar        0.006369
# Infiniti      0.006369
# Name: proportion, dtype: float64

# %%
data["Manufacturer"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Manufacturer'>

# %%
data['Model'].nunique() #returns the number of values which are unique
# Out:
# 156

# %%
data['Model'].duplicated().sum()  #duplicated model k kitne duplicated hai
# Out:
# 1

# %%
data[data['Model'].duplicated()]
# Out:
#     Manufacturer Model  Sales_in_thousands  four_year_resale_value  \
# 114     Plymouth  Neon              32.734                    7.75
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 114    Passenger               12.64          2.0       132.0      105.0
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 114   74.4   174.4        2.559           12.5             29.0

# %%
data[data['Model']=='Neon']
# Out:
#     Manufacturer Model  Sales_in_thousands  four_year_resale_value  \
# 35         Dodge  Neon              76.034                    7.75
# 114     Plymouth  Neon              32.734                    7.75
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 35     Passenger               12.64          2.0       132.0      105.0
# 114    Passenger               12.64          2.0       132.0      105.0
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 35    74.4   174.4        2.567           12.5             29.0
# 114   74.4   174.4        2.559           12.5             29.0

# %%
df=data

# %% [markdown]
# ### Drop Column

# %%
df.drop(columns=['Model'],inplace=True)

# %%
df.head()
# Out:
#   Manufacturer  Sales_in_thousands  four_year_resale_value Vehicle_type  \
# 0        Acura              16.919                  16.360    Passenger
# 1        Acura              39.384                  19.875    Passenger
# 2        Acura              14.114                  18.225    Passenger
# 3        Acura               8.588                  29.725    Passenger
# 4         Audi              20.397                  22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
#    Curb weight  Fuel_capacity  Fuel_efficiency
# ...

# %%
#here column of Model was succesfully droped

# %%
data['Vehicle_type'].nunique()
# Out:
# 2

# %%
data['Vehicle_type'].duplicated().sum()
# Out:
# 155

# %%
data["Vehicle_type"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Vehicle_type'>

# %%
data['Vehicle_type'].value_counts()
# Out:
# Vehicle_type
# Passenger    116
# Car           41
# Name: count, dtype: int64

# %%
data['Vehicle_type'].value_counts(normalize=True)    #Normalize for find percentage here passenger 73% and 27% cars
# Out:
# Vehicle_type
# Passenger    0.738854
# Car          0.261146
# Name: proportion, dtype: float64

# %% [markdown]
# 1. 116 Passengers
# 2. 41 cars
# 3. Passenger Car stand aproximate 74% in data Vehicle_type.
# 4. Car has 26% in Vehicle_type.
# 5. Vehicle_type have 155 duplicated values.
# 6.

# %% [markdown]
# ### Numercal column

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Manufacturer            157 non-null    object
#  1   Sales_in_thousands      157 non-null    float64
#  2   four_year_resale_value  121 non-null    float64
#  3   Vehicle_type            157 non-null    object
#  4   Price_in_thousands      155 non-null    float64
#  5   Engine_size             156 non-null    float64
#  6   Horsepower              156 non-null    float64
#  7   Wheelbase               156 non-null    float64
#  8   Width                   156 non-null    float64
#  9   Length                  156 non-null    float64
#  10  Curb weight             155 non-null    float64
#  11  Fuel_capacity           156 non-null    float64
#  12  Fuel_efficiency         154 non-null    float64
# dtypes: float64(11), object(2)
# memory usage: 16.1+ KB

# %%
data.dtypes[data.dtypes!='Object'].index
# Out:
# Index(['Manufacturer', 'Sales_in_thousands', 'four_year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb weight', 'Fuel_capacity',
#        'Fuel_efficiency'],
#       dtype='object')

# %%
df=data[['Manufacturer', 'Sales_in_thousands', 'four_year_resale_value',
       'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
       'Wheelbase', 'Width', 'Length', 'Curb weight', 'Fuel_capacity',
       'Fuel_efficiency']]

# %%
df.describe().T
# Out:
#                         count        mean        std      min       25%  \
# Sales_in_thousands      157.0   52.998076  68.029422    0.110   14.1140
# four_year_resale_value  121.0   18.072975  11.453384    5.160   11.2600
# Price_in_thousands      155.0   27.390755  14.351653    9.235   18.0175
# Engine_size             156.0    3.060897   1.044653    1.000    2.3000
# Horsepower              156.0  185.948718  56.700321   55.000  149.5000
# Wheelbase               156.0  107.487179   7.641303   92.600  103.0000
# Width                   156.0   71.150000   3.451872   62.600   68.4000
# Length                  156.0  187.343590  13.431754  149.400  177.5750
# Curb weight             155.0    3.378026   0.630502    1.895    2.9710
# Fuel_capacity           156.0   17.951923   3.887921   10.300   15.8000
# Fuel_efficiency         154.0   23.844156   4.282706   15.000   21.0000
#
#                             50%       75%      max
# Sales_in_thousands       29.450   67.9560  540.561
# ...

# %%
data_1=data[['Sales_in_thousands', 'four_year_resale_value']]

# %%
data_1
# Out:
#      Sales_in_thousands  four_year_resale_value
# 0                16.919                  16.360
# 1                39.384                  19.875
# 2                14.114                  18.225
# 3                 8.588                  29.725
# 4                20.397                  22.255
# ..                  ...                     ...
# 152               3.545                     NaN
# 153              15.245                     NaN
# 154              17.531                     NaN
# 155               3.493                     NaN
# 156              18.969                     NaN
#
# [157 rows x 2 columns]

# %%
data['Sales_in_thousands'].min()
# Out:
# 0.11

# %%
data['Sales_in_thousands'].max()
# Out:
# 540.561

# %%
data['four_year_resale_value'].min()
# Out:
# 5.16

# %%
data['four_year_resale_value'].max()
# Out:
# 67.55

# %%
data['Sales_in_thousands'].mean()
# Out:
# 52.99807643312102

# %%
data[data['Sales_in_thousands']==540.561]     # Car Max Sales
# Out:
#    Manufacturer     Model  Sales_in_thousands  four_year_resale_value  \
# 56         Ford  F-Series             540.561                  15.075
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 56          Car              26.935          4.6       220.0      138.5
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 56   79.1   224.5        4.241           25.1             18.0

# %%
a=data[data['Vehicle_type']=='Passenger']

# %%
a.describe().T
# Out:
#                         count        mean        std      min       25%  \
# Sales_in_thousands      116.0   43.234345  50.557875    0.110   10.8290
# four_year_resale_value   91.0   18.658187  12.880853    5.160   10.5925
# Price_in_thousands      115.0   27.763200  15.566574    9.235   17.1960
# Engine_size             116.0    2.902586   1.030699    1.000    2.0000
# Horsepower              116.0  185.793103  61.625872   55.000  140.0000
# Wheelbase               116.0  105.751724   5.769537   92.600  102.4000
# Width                   116.0   70.652586   3.001433   62.600   68.3000
# Length                  116.0  186.280172  12.785809  149.400  176.6750
# Curb weight             115.0    3.184261   0.474749    1.895    2.9080
# Fuel_capacity           116.0   16.592241   2.575542   10.300   15.0000
# Fuel_efficiency         114.0   25.298246   3.645654   16.000   23.0000
#
#                              50%        75%      max
# ...

# %%
data[data['Sales_in_thousands']==0.11]
# Out:
#    Manufacturer   Model  Sales_in_thousands  four_year_resale_value  \
# 83   Mitsubishi  3000GT                0.11                   20.94
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 83    Passenger               25.45          3.0       161.0       97.2
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 83   72.4   180.3        3.131           19.8             21.0

# %%
data[data['four_year_resale_value']==67.550]
# Out:
#     Manufacturer           Model  Sales_in_thousands  four_year_resale_value  \
# 126      Porsche  Carrera Cabrio               1.866                   67.55
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 126    Passenger               74.97          3.4       300.0       92.6
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 126   69.5   174.5        3.075           17.0             23.0

# %%
data[data['four_year_resale_value']==5.160]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %%
data[data['Price_in_thousands']==85.500]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 99   Mercedes-B  CL500               0.954                     NaN
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 99    Passenger                85.5          5.0       302.0      113.6
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 99   73.1   196.6        4.115           23.2             20.0

# %%
data[data['Price_in_thousands']==9.235]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %%
data[data['Engine_size']==8.000]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 39        Dodge  Viper               0.916                   58.47
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 39    Passenger              69.725          8.0       450.0       96.2
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 39   75.7   176.7        3.375           19.0             16.0

# %%
data[data['Engine_size']==1.000]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %%
data[data['Horsepower']==450.000]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 39        Dodge  Viper               0.916                   58.47
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 39    Passenger              69.725          8.0       450.0       96.2
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 39   75.7   176.7        3.375           19.0             16.0

# %%
data[data['Horsepower']==55.000]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %%
data[data['Wheelbase']==138.700]
# Out:
#    Manufacturer       Model  Sales_in_thousands  four_year_resale_value  \
# 40        Dodge  Ram Pickup             227.061                   15.06
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 40          Car               19.46          5.2       230.0      138.7
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 40   79.3   224.2         4.47           26.0             17.0

# %%
data[data['Wheelbase']==92.600]
# Out:
#     Manufacturer           Model  Sales_in_thousands  four_year_resale_value  \
# 125      Porsche   Carrera Coupe               1.280                  60.625
# 126      Porsche  Carrera Cabrio               1.866                  67.550
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 125    Passenger               71.02          3.4       300.0       92.6
# 126    Passenger               74.97          3.4       300.0       92.6
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 125   69.5   174.5        3.032           17.0             21.0
# 126   69.5   174.5        3.075           17.0             23.0

# %%
data[data['Width']==79.900]
# Out:
#    Manufacturer      Model  Sales_in_thousands  four_year_resale_value  \
# 78      Lincoln  Navigator              22.925                     NaN
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 78          Car               42.66          5.4       300.0      119.0
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 78   79.9   204.8        5.393           30.0             15.0

# %%
data[data['Width']==62.600]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %%
data[data['Length']==224.500]
# Out:
#    Manufacturer     Model  Sales_in_thousands  four_year_resale_value  \
# 56         Ford  F-Series             540.561                  15.075
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 56          Car              26.935          4.6       220.0      138.5
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 56   79.1   224.5        4.241           25.1             18.0

# %%
data[data['Length']==149.400]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %%
data[data['Curb weight']==5.572]
# Out:
#    Manufacturer     Model  Sales_in_thousands  four_year_resale_value  \
# 18     Cadillac  Escalade              14.785                     NaN
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 18          Car              46.225          5.7       255.0      117.5
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 18   77.0   201.2        5.572           30.0             15.0

# %%
data[data['Curb weight']==1.895]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %%
data[data['Fuel_capacity']==32.000]
# Out:
#    Manufacturer      Model  Sales_in_thousands  four_year_resale_value  \
# 41        Dodge  Ram Wagon              16.767                  15.510
# 42        Dodge    Ram Van              31.038                  13.425
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 41          Car              21.315          3.9       175.0      109.6
# 42          Car              18.575          3.9       175.0      127.2
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 41   78.8   192.6        4.245           32.0             15.0
# 42   78.8   208.5        4.298           32.0             16.0

# %%
data[data['Fuel_capacity']==10.300]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %%
data[data['Fuel_efficiency']==45.000]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %%
data[data['Fuel_efficiency']==15.000]
# Out:
#     Manufacturer         Model  Sales_in_thousands  four_year_resale_value  \
# 18      Cadillac      Escalade              14.785                     NaN
# 41         Dodge     Ram Wagon              16.767                   15.51
# 74         Lexus         LX470               9.126                     NaN
# 78       Lincoln     Navigator              22.925                     NaN
# 144       Toyota  Land Cruiser               9.835                   34.08
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 18           Car              46.225          5.7       255.0      117.5
# 41           Car              21.315          3.9       175.0      109.6
# 74           Car              60.105          4.7       230.0      112.2
# 78           Car              42.660          5.4       300.0      119.0
# 144          Car              51.728          4.7       230.0      112.2
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# ...

# %% [markdown]
# # Vehicle_Type Passenger

# %% [markdown]
# ## Sales_in_Thousands

# %% [markdown]
# ***In Passenger maximum Sales is Toyota Camry***

# %%
data[data['Sales_in_thousands']==247.994]
# Out:
#     Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 137       Toyota  Camry             247.994                  13.245
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 137    Passenger              17.518          2.2       133.0      105.2
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 137   70.1   188.5        2.998           18.5             27.0

# %% [markdown]
# ***In Passenger minimum Sales is Mitsubishi 3000GT***

# %%
data[data['Sales_in_thousands']==0.110]
# Out:
#    Manufacturer   Model  Sales_in_thousands  four_year_resale_value  \
# 83   Mitsubishi  3000GT                0.11                   20.94
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 83    Passenger               25.45          3.0       161.0       97.2
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 83   72.4   180.3        3.131           19.8             21.0

# %% [markdown]
# ## Four_Year_Resale_Value

# %% [markdown]
# ***Passenger Maximum Four_Year_Resale_Value is Porsche Carrera Cabrio***

# %%
data[data['four_year_resale_value']==67.550]
# Out:
#     Manufacturer           Model  Sales_in_thousands  four_year_resale_value  \
# 126      Porsche  Carrera Cabrio               1.866                   67.55
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 126    Passenger               74.97          3.4       300.0       92.6
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 126   69.5   174.5        3.075           17.0             23.0

# %% [markdown]
# ***Passenger Minimum Four_Year_Resale_Value is Chevrolet Metro***

# %%
data[data['four_year_resale_value']==5.160]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %% [markdown]
# ## Price_in_thousands

# %% [markdown]
# ***Passenger Maximum Price_in_Thousands is Mercedes-B CL500***

# %%
data[data['Price_in_thousands']==85.500]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 99   Mercedes-B  CL500               0.954                     NaN
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 99    Passenger                85.5          5.0       302.0      113.6
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 99   73.1   196.6        4.115           23.2             20.0

# %% [markdown]
# ***Passenger Minimum Price_in_Thousands is Chevrolet Metro***

# %%
data[data['Price_in_thousands']==9.235]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %% [markdown]
# ## Engine_size

# %% [markdown]
# ***Dodge Viper has Maximum Engine_size in Passenger***

# %%
data[data['Engine_size']==8.000]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 39        Dodge  Viper               0.916                   58.47
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 39    Passenger              69.725          8.0       450.0       96.2
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 39   75.7   176.7        3.375           19.0             16.0

# %% [markdown]
# ***Chevrolet Metro has Minimum Engine_size in Passenger***

# %%
data[data['Engine_size']==1.000]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %% [markdown]
# ## Horsepower

# %% [markdown]
# ***Dodge Viper have Maximum Horspower in Passenger***

# %%
data[data['Horsepower']==450.000]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 39        Dodge  Viper               0.916                   58.47
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 39    Passenger              69.725          8.0       450.0       96.2
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 39   75.7   176.7        3.375           19.0             16.0

# %% [markdown]
# ***Chevrolet Metro have Minimum Horspower in Passenger***

# %%
data[data['Horsepower']==55.000]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %% [markdown]
# ## Wheelbase

# %% [markdown]
# ***Mercedes-B S-Class has Maximum Wheelbase in Passenger***

# %%
data[data['Wheelbase']==121.500]
# Out:
#    Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 94   Mercedes-B  S-Class              16.774                  50.375
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 94    Passenger                69.7          4.3       275.0      121.5
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 94   73.1   203.1        4.133           23.2             21.0

# %% [markdown]
# ***Porsche Carrera Coupe & Porsche Carrera Cabrio has Minimum Wheelbase in Passenger***

# %%
data[data['Wheelbase']==92.600]
# Out:
#     Manufacturer           Model  Sales_in_thousands  four_year_resale_value  \
# 125      Porsche   Carrera Coupe               1.280                  60.625
# 126      Porsche  Carrera Cabrio               1.866                  67.550
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 125    Passenger               71.02          3.4       300.0       92.6
# 126    Passenger               74.97          3.4       300.0       92.6
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 125   69.5   174.5        3.032           17.0             21.0
# 126   69.5   174.5        3.075           17.0             23.0

# %% [markdown]
# ## Width

# %% [markdown]
# ***Ford, Lincoln and Mercury Has Maximum Width in Passenger***

# %%
data[data['Width']==78.200]
# Out:
#    Manufacturer           Model  Sales_in_thousands  four_year_resale_value  \
# 51         Ford  Crown Victoria              63.403                  14.210
# 77      Lincoln        Town car              48.911                  21.725
# 89      Mercury   Grand Marquis              81.174                  14.875
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 51    Passenger              22.195          4.6       200.0      114.7
# 77    Passenger              43.330          4.6       215.0      117.7
# 89    Passenger              22.605          4.6       200.0      114.7
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 51   78.2   212.0        3.908           19.0             21.0
# 77   78.2   215.3        4.121           19.0             21.0
# 89   78.2   212.0        3.958           19.0             21.0

# %% [markdown]
# ***Chevrolet Metro Has Minimum Width in Passenger***

# %%
data[data['Width']==62.600]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %% [markdown]
# ## Length

# %% [markdown]
# ***Lincoln Town car have Maximum Length in Passenger***

# %%
data[data['Length']==215.300]
# Out:
#    Manufacturer     Model  Sales_in_thousands  four_year_resale_value  \
# 77      Lincoln  Town car              48.911                  21.725
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 77    Passenger               43.33          4.6       215.0      117.7
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 77   78.2   215.3        4.121           19.0             21.0

# %% [markdown]
# ***Chevrolet Metro have Minimum Length in Passenger***

# %%
data[data['Length']==149.400]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %% [markdown]
# ## Crub Weight

# %% [markdown]
# ***Mercedes-B S-Class has Maximum Curb Weight in Passenger***

# %%
data[data['Curb weight']==4.133]
# Out:
#    Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 94   Mercedes-B  S-Class              16.774                  50.375
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 94    Passenger                69.7          4.3       275.0      121.5
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 94   73.1   203.1        4.133           23.2             21.0

# %% [markdown]
# ***Chevrolet Metro has Minimum Curb Weight in Passenger***

# %%
data[data['Curb weight']==1.895]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %% [markdown]
# ## Fuel_Capacity

# %% [markdown]
# ***Audi	A8 Has Maximum Fuel_capacity in Passenger***

# %%
data[data['Fuel_capacity']==23.700]
# Out:
#   Manufacturer Model  Sales_in_thousands  four_year_resale_value Vehicle_type  \
# 6         Audi    A8                1.38                    39.0    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 6                62.0          4.2       310.0      113.0   74.0   198.2
#
#    Curb weight  Fuel_capacity  Fuel_efficiency
# 6        3.902           23.7             21.0

# %% [markdown]
# ***Chevrolet Metro	 Has Minimum Fuel_capacity in Passenger***

# %%
data[data['Fuel_capacity']==10.300]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %% [markdown]
# ## Fuel_Efficiency

# %% [markdown]
# ***Chevrolet Metro Has Maximum Fuel_efficiency in Passenger***

# %%
data[data['Fuel_efficiency']==45.000]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 26   62.6   149.4        1.895           10.3             45.0

# %% [markdown]
# ***Dodge Viper, Dodge Ram Van,  Ford Expedition	Has Minimum Fuel_efficiency in Passenger***

# %%
data[data['Fuel_efficiency']==16.000]
# Out:
#    Manufacturer       Model  Sales_in_thousands  four_year_resale_value  \
# 39        Dodge       Viper               0.916                  58.470
# 42        Dodge     Ram Van              31.038                  13.425
# 54         Ford  Expedition             125.338                  23.575
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 39    Passenger              69.725          8.0       450.0       96.2
# 42          Car              18.575          3.9       175.0      127.2
# 54          Car              36.135          4.6       240.0      119.0
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 39   75.7   176.7        3.375           19.0             16.0
# 42   78.8   208.5        4.298           32.0             16.0
# 54   78.7   204.6        4.808           26.0             16.0

# %% [markdown]
# # Vehicle_Type Car

# %%
a=data[data['Vehicle_type']=='Car']

# %%
a.describe().T
# Out:
#                         count        mean        std      min       25%  \
# Sales_in_thousands       41.0   80.622293  98.192626    9.126   24.3610
# four_year_resale_value   30.0   16.297833   4.854535    7.850   13.4375
# Price_in_thousands       40.0   26.319975  10.169436   11.528   19.9625
# Engine_size              40.0    3.520000   0.956007    2.000    2.9250
# Horsepower               40.0  186.400000  39.730373  119.000  161.2500
# Wheelbase                40.0  112.520000   9.948282   93.400  106.2000
# Width                    40.0   72.592500   4.233468   66.500   69.4000
# Length                   40.0  190.427500  14.894862  152.000  180.4750
# Curb weight              40.0    3.935100   0.694206    2.580    3.5235
# Fuel_capacity            40.0   21.895000   4.367006   15.100   19.4000
# Fuel_efficiency          40.0   19.700000   3.106651   15.000   17.7500
#
#                             50%        75%      max
# ...

# %% [markdown]
# ## Sales_in_thousands

# %% [markdown]
# ***Ford F-Series is the Maximum Sales in Car***

# %%
data[data['Sales_in_thousands']==540.561]
# Out:
#    Manufacturer     Model  Sales_in_thousands  four_year_resale_value  \
# 56         Ford  F-Series             540.561                  15.075
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 56          Car              26.935          4.6       220.0      138.5
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 56   79.1   224.5        4.241           25.1             18.0

# %% [markdown]
# ***Lexus LX470 is the Minimum Sales in Car***

# %%
data[data['Sales_in_thousands']==9.126]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 74        Lexus  LX470               9.126                     NaN
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 74          Car              60.105          4.7       230.0      112.2
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 74   76.4   192.5        5.401           25.4             15.0

# %% [markdown]
# ## Four_Year_resale_value

# %% [markdown]
# ***Toyota Land Cruiser Maximum Four_Year_resale_value***

# %%
data[data['four_year_resale_value']==34.080]
# Out:
#     Manufacturer         Model  Sales_in_thousands  four_year_resale_value  \
# 144       Toyota  Land Cruiser               9.835                   34.08
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 144          Car              51.728          4.7       230.0      112.2
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 144   76.4   192.5        5.115           25.4             15.0

# %% [markdown]
# ***Ford	Ranger Minimum Four_Year_resale_value***

# %%
data[data['four_year_resale_value']==7.850]
# Out:
#    Manufacturer   Model  Sales_in_thousands  four_year_resale_value  \
# 55         Ford  Ranger              220.65                    7.85
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 55          Car               12.05          2.5       119.0      117.5
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 55   69.4   200.7        3.086           20.0             23.0

# %% [markdown]
# # Price_in_thousands

# %% [markdown]
# ***Lexus LX470 has Maximum Price in Thousands***

# %%
data[data['Price_in_thousands']==60.105]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 74        Lexus  LX470               9.126                     NaN
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 74          Car              60.105          4.7       230.0      112.2
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 74   76.4   192.5        5.401           25.4             15.0

# %% [markdown]
# ***Toyota Tacoma has Minimum Price in Thousands***

# %%
data[data['Price_in_thousands']==11.528]
# Out:
#     Manufacturer   Model  Sales_in_thousands  four_year_resale_value  \
# 140       Toyota  Tacoma              84.087                   9.575
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 140          Car              11.528          2.4       142.0      103.3
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 140   66.5   178.7         2.58           15.1             23.0

# %% [markdown]
# # Engine_size

# %% [markdown]
# ***Cadillac	Escalade, Chevrolet	Corvette Have Maximum Engine in Car***

# %%
data[data['Engine_size']==5.700]
# Out:
#    Manufacturer     Model  Sales_in_thousands  four_year_resale_value  \
# 18     Cadillac  Escalade              14.785                     NaN
# 24    Chevrolet  Corvette              17.947                  36.225
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 18          Car              46.225          5.7       255.0      117.5
# 24    Passenger              45.705          5.7       345.0      104.5
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 18   77.0   201.2        5.572           30.0             15.0
# 24   73.6   179.7        3.210           19.1             22.0

# %% [markdown]
# ***Chrysler	Cirrus, Dodge Neon........Volkswagen Beetle have minimum Engine sizw***

# %%
data[data['Engine_size']==2.000]
# Out:
#     Manufacturer     Model  Sales_in_thousands  four_year_resale_value  \
# 31      Chrysler    Cirrus              32.306                  12.640
# 35         Dodge      Neon              76.034                   7.750
# 46          Ford    Escort              70.227                   7.425
# 50          Ford     Focus             175.670                     NaN
# 59         Honda      CR-V              73.203                  17.710
# 63       Hyundai   Elantra              66.692                   7.825
# 86       Mercury  Mystique              14.351                   8.800
# 87       Mercury    Cougar              26.529                  13.890
# 114     Plymouth      Neon              32.734                   7.750
# 115     Plymouth    Breeze               5.240                   9.800
# 128         Saab    03-Sep              12.115                     NaN
# 142       Toyota      RAV4              25.106                  13.325
# ...

# %% [markdown]
# ## Horsepower

# %% [markdown]
# ***Lexus GS400, Lincoln	Navigator, Porsche Carrera Coupe, Porsche Carrera Cabrio Have Maximum Horsepower cars***

# %%
data[data['Horsepower']==300.000]
# Out:
#     Manufacturer           Model  Sales_in_thousands  four_year_resale_value  \
# 72         Lexus           GS400               3.334                     NaN
# 78       Lincoln       Navigator              22.925                     NaN
# 125      Porsche   Carrera Coupe               1.280                  60.625
# 126      Porsche  Carrera Cabrio               1.866                  67.550
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 72     Passenger              46.305          4.0       300.0      110.2
# 78           Car              42.660          5.4       300.0      119.0
# 125    Passenger              71.020          3.4       300.0       92.6
# 126    Passenger              74.970          3.4       300.0       92.6
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 72    70.9   189.2        3.693           19.8             21.0
# 78    79.9   204.8        5.393           30.0             15.0
# ...

# %% [markdown]
# ***Ford	Ranger has Minimum Horsepower Car***

# %%
data[data['Horsepower']==119.000]
# Out:
#    Manufacturer   Model  Sales_in_thousands  four_year_resale_value  \
# 55         Ford  Ranger              220.65                    7.85
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 55          Car               12.05          2.5       119.0      117.5
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 55   69.4   200.7        3.086           20.0             23.0

# %% [markdown]
# ## Wheelbase

# %% [markdown]
# ***Dodge Ram Pickup Has Maximum Wheelbase***

# %%
data[data['Wheelbase']==138.700]
# Out:
#    Manufacturer       Model  Sales_in_thousands  four_year_resale_value  \
# 40        Dodge  Ram Pickup             227.061                   15.06
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 40          Car               19.46          5.2       230.0      138.7
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 40   79.3   224.2         4.47           26.0             17.0

# %% [markdown]
# ***Jeep	Wrangler Has Minimum Wheelbase***

# %%
data[data['Wheelbase']==93.400]
# Out:
#    Manufacturer     Model  Sales_in_thousands  four_year_resale_value  \
# 67         Jeep  Wrangler              55.557                  13.475
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 67          Car               14.46          2.5       120.0       93.4
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 67   66.7   152.0        3.045           19.0             17.0

# %% [markdown]
# ## Width

# %% [markdown]
# ***Lincoln Navigator has Maximum Width Car***

# %%
data[data['Width']==79.900]
# Out:
#    Manufacturer      Model  Sales_in_thousands  four_year_resale_value  \
# 78      Lincoln  Navigator              22.925                     NaN
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 78          Car               42.66          5.4       300.0      119.0
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 78   79.9   204.8        5.393           30.0             15.0

# %% [markdown]
# ***Mitsubishi Mirage,Nissan	Frontier,...,Toyota	4Runner has Minimum Width Car***

# %%
data[data['Width']==66.500]
# Out:
#     Manufacturer     Model  Sales_in_thousands  four_year_resale_value  \
# 79    Mitsubishi    Mirage              26.232                   8.325
# 107       Nissan  Frontier              65.005                     NaN
# 140       Toyota    Tacoma              84.087                   9.575
# 143       Toyota   4Runner              68.411                  19.425
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 79     Passenger              13.987          1.8       113.0       98.4
# 107          Car              17.890          3.3       170.0      116.1
# 140          Car              11.528          2.4       142.0      103.3
# 143          Car              22.288          2.7       150.0      105.3
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 79    66.5   173.6        2.250           13.2             30.0
# 107   66.5   196.1        3.217           19.4             18.0
# ...

# %% [markdown]
# ## Length

# %% [markdown]
# ***Ford	F-Series Have Maximum Length Cars***

# %%
data[data['Length']==224.500]
# Out:
#    Manufacturer     Model  Sales_in_thousands  four_year_resale_value  \
# 56         Ford  F-Series             540.561                  15.075
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 56          Car              26.935          4.6       220.0      138.5
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 56   79.1   224.5        4.241           25.1             18.0

# %% [markdown]
# ***Jeep	Wrangler Have Minimum Length Cars***

# %%
data[data['Length']==152.000]
# Out:
#    Manufacturer     Model  Sales_in_thousands  four_year_resale_value  \
# 67         Jeep  Wrangler              55.557                  13.475
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 67          Car               14.46          2.5       120.0       93.4
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 67   66.7   152.0        3.045           19.0             17.0

# %% [markdown]
# ## Curb weight

# %% [markdown]
# ***Cadillac	Escalade has Maximum Curb weight Car***

# %%
data[data['Curb weight']==5.572]
# Out:
#    Manufacturer     Model  Sales_in_thousands  four_year_resale_value  \
# 18     Cadillac  Escalade              14.785                     NaN
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 18          Car              46.225          5.7       255.0      117.5
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 18   77.0   201.2        5.572           30.0             15.0

# %% [markdown]
# ***Toyota Tacoma has Minimum Curb weight Car***

# %%
data[data['Curb weight']==2.580]
# Out:
#     Manufacturer   Model  Sales_in_thousands  four_year_resale_value  \
# 140       Toyota  Tacoma              84.087                   9.575
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 140          Car              11.528          2.4       142.0      103.3
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 140   66.5   178.7         2.58           15.1             23.0

# %% [markdown]
# ## Fuel_capacity

# %% [markdown]
# ***Dodge Ram Wagon, Dodge Ram Van has Maximum Fuel Capacity Car***

# %%
data[data['Fuel_capacity']==32.000]
# Out:
#    Manufacturer      Model  Sales_in_thousands  four_year_resale_value  \
# 41        Dodge  Ram Wagon              16.767                  15.510
# 42        Dodge    Ram Van              31.038                  13.425
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 41          Car              21.315          3.9       175.0      109.6
# 42          Car              18.575          3.9       175.0      127.2
#
#     Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 41   78.8   192.6        4.245           32.0             15.0
# 42   78.8   208.5        4.298           32.0             16.0

# %% [markdown]
# ***Toyota Tacoma have Minimum Fuel_Capacity Car***

# %%
data[data['Fuel_capacity']==15.100]
# Out:
#     Manufacturer   Model  Sales_in_thousands  four_year_resale_value  \
# 140       Toyota  Tacoma              84.087                   9.575
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 140          Car              11.528          2.4       142.0      103.3
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# 140   66.5   178.7         2.58           15.1             23.0

# %% [markdown]
# ## Fuel_efficiency

# %% [markdown]
# ***Chevrolet Cavalier,Chevrolet	Monte Carlo,.....,Volkswagen Passat have Minimum Fuel_capacity***

# %%
data[data['Fuel_efficiency']==27.000]
# Out:
#     Manufacturer        Model  Sales_in_thousands  four_year_resale_value  \
# 4           Audi           A4              20.397                  22.255
# 19     Chevrolet     Cavalier             145.519                   9.250
# 22     Chevrolet  Monte Carlo              42.593                  11.525
# 27     Chevrolet       Impala             107.995                     NaN
# 31      Chrysler       Cirrus              32.306                  12.640
# 58         Honda       Accord             230.902                  13.210
# 63       Hyundai      Elantra              66.692                   7.825
# 97    Mercedes-B       SLK230               1.526                     NaN
# 110   Oldsmobile        Alero              80.255                     NaN
# 115     Plymouth       Breeze               5.240                   9.800
# 118      Pontiac      Sunfire              51.645                  13.790
# 132       Saturn           LW               8.472                     NaN
# ...

# %% [markdown]
# ***Cadillac	Escalade, Dodge	Ram Wagon,...,Toyota Land Cruiser Minimum Fuel Effeciency Car***

# %%
data[data['Fuel_efficiency']==15.000]
# Out:
#     Manufacturer         Model  Sales_in_thousands  four_year_resale_value  \
# 18      Cadillac      Escalade              14.785                     NaN
# 41         Dodge     Ram Wagon              16.767                   15.51
# 74         Lexus         LX470               9.126                     NaN
# 78       Lincoln     Navigator              22.925                     NaN
# 144       Toyota  Land Cruiser               9.835                   34.08
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 18           Car              46.225          5.7       255.0      117.5
# 41           Car              21.315          3.9       175.0      109.6
# 74           Car              60.105          4.7       230.0      112.2
# 78           Car              42.660          5.4       300.0      119.0
# 144          Car              51.728          4.7       230.0      112.2
#
#      Width  Length  Curb weight  Fuel_capacity  Fuel_efficiency
# ...

# %%
data['Sales_in_thousands'].mean()
# Out:
# 52.99807643312102

# %%
data[data['Sales_in_thousands']>=52.99807643312102]
# Out:
#     Manufacturer           Model  Sales_in_thousands  four_year_resale_value  \
# 10         Buick         Century              91.561                  12.475
# 13         Buick         LeSabre              83.257                  13.360
# 14      Cadillac         DeVille              63.729                  22.525
# 19     Chevrolet        Cavalier             145.519                   9.250
# 20     Chevrolet          Malibu             135.126                  11.225
# 27     Chevrolet          Impala             107.995                     NaN
# 33      Chrysler  Town & Country              53.480                  19.540
# 35         Dodge            Neon              76.034                   7.750
# 37         Dodge         Stratus              71.186                  10.185
# 38         Dodge        Intrepid              88.028                  12.275
# 40         Dodge      Ram Pickup             227.061                  15.060
# ...

# %%
data['Sales_in_thousands'].describe()
# Out:
# count    157.000000
# mean      52.998076
# std       68.029422
# min        0.110000
# 25%       14.114000
# 50%       29.450000
# 75%       67.956000
# max      540.561000
# Name: Sales_in_thousands, dtype: float64

# %%
data['Sales_in_thousands'].skew()
# Out:
# 3.408518366470572

# %% [markdown]
# ## Sales_in_thousands Histogram plot

# %%
plt.hist(data['Sales_in_thousands']) #histogram plot 
plt.show()

# %% [markdown]
# ## Sales_in_thousands Distplot Graph

# %%
sns.distplot(data['Sales_in_thousands'])   #distribution plot seaborn
plt.show()
# Out:
# C:\Users\Sai\AppData\Local\Temp\ipykernel_18812\2160948385.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Sales_in_thousands'])   #distribution plot seaborn

# %% [markdown]
# resele value,price in thousands,   baaki numerical value ka distplot bnana hai

# %% [markdown]
# ## four_year_resale_value distplot

# %%
sns.distplot(data['four_year_resale_value'])   #distribution plot seaborn
plt.show()
# Out:
# C:\Users\Sai\AppData\Local\Temp\ipykernel_18812\873534731.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['four_year_resale_value'])   #distribution plot seaborn

# %% [markdown]
# ## Price_in_thousands

# %%
sns.distplot(data['Price_in_thousands'])   #distribution plot seaborn
plt.show()
# Out:
# C:\Users\Sai\AppData\Local\Temp\ipykernel_18812\3141594413.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price_in_thousands'])   #distribution plot seaborn

# %% [markdown]
# ## Engine_size

# %%
sns.distplot(data['Engine_size'])   #distribution plot seaborn
plt.show()
# Out:
# C:\Users\Sai\AppData\Local\Temp\ipykernel_18812\2585066980.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Engine_size'])   #distribution plot seaborn

# %% [markdown]
# ## Horsepower

# %%
sns.distplot(data['Horsepower'])   #distribution plot seaborn
plt.show()
# Out:
# C:\Users\Sai\AppData\Local\Temp\ipykernel_18812\1125412772.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Horsepower'])   #distribution plot seaborn

# %% [markdown]
# ## Wheelbase

# %%
sns.distplot(data['Wheelbase'])   #distribution plot seaborn
plt.show()
# Out:
# C:\Users\Sai\AppData\Local\Temp\ipykernel_18812\1260581727.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Wheelbase'])   #distribution plot seaborn

# %% [markdown]
# ## Width

# %%
sns.distplot(data['Width'])   #distribution plot seaborn
plt.show()
# Out:
# C:\Users\Sai\AppData\Local\Temp\ipykernel_18812\3126140153.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Width'])   #distribution plot seaborn

# %% [markdown]
# ## Length

# %%
sns.distplot(data['Length'])   #distribution plot seaborn
plt.show()
# Out:
# C:\Users\Sai\AppData\Local\Temp\ipykernel_18812\4020294510.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Length'])   #distribution plot seaborn

# %% [markdown]
# ## Curb weight

# %%
sns.distplot(data['Curb weight'])   #distribution plot seaborn
plt.show()
# Out:
# C:\Users\Sai\AppData\Local\Temp\ipykernel_18812\883676614.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Curb weight'])   #distribution plot seaborn

# %% [markdown]
# ## Fuel_capacity

# %%
sns.distplot(data['Fuel_capacity'])   #distribution plot seaborn
plt.show()
# Out:
# C:\Users\Sai\AppData\Local\Temp\ipykernel_18812\2051306368.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Fuel_capacity'])   #distribution plot seaborn

# %% [markdown]
# ## Fuel_efficiency

# %%
sns.distplot(data['Fuel_efficiency'])   #distribution plot seaborn
plt.show()
# Out:
# C:\Users\Sai\AppData\Local\Temp\ipykernel_18812\3443829686.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Fuel_efficiency'])   #distribution plot seaborn

# %%
d1=['Sales_in_thousands', 'four_year_resale_value', 'Price_in_thousands',
       'Engine_size', 'Horsepower', 'Wheelbase', 'Width', 'Length',
       'Curb weight', 'Fuel_capacity', 'Fuel_efficiency']
for i in d1:
    sns.distplot(data[i])
    plt.title(f'{i} Distribution')
    plt.show()
# Out:
# C:\Users\Sai\AppData\Local\Temp\ipykernel_18812\3907812443.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[i])
# C:\Users\Sai\AppData\Local\Temp\ipykernel_18812\3907812443.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[i])
# ...

# %% [markdown]
# # Bivariante

# %% [markdown]
# ## Bivariant ek numerical ek categorical value ke analysis ko bivariant kahte hai

# %%
pd.crosstab(data['Manufacturer'],data['Vehicle_type']=='car')
# Out:
# Vehicle_type  False
# Manufacturer
# Acura             4
# Audi              3
# BMW               3
# Buick             4
# Cadillac          5
# Chevrolet         9
# Chrysler          7
# Dodge            11
# Ford             11
# Honda             5
# Hyundai           3
# Infiniti          1
# Jaguar            1
# Jeep              3
# Lexus             6
# Lincoln           3
# Mercedes-B        9
# Mercury           6
# Mitsubishi        7
# Nissan            7
# Oldsmobile        6
# Plymouth          4
# Pontiac           6
# Porsche           3
# Saab              2
# Saturn            5
# Subaru            2
# Toyota            9
# Volkswagen        6
# Volvo             6

# %%
a=data[data['Vehicle_type']=='Car']
pd.crosstab(a['Manufacturer'],a['Vehicle_type'])
# Out:
# Vehicle_type  Car
# Manufacturer
# Cadillac        1
# Chrysler        1
# Dodge           6
# Ford            5
# Honda           3
# Jeep            3
# Lexus           2
# Lincoln         1
# Mercedes-B      1
# Mercury         2
# Mitsubishi      2
# Nissan          4
# Oldsmobile      2
# Plymouth        1
# Pontiac         1
# Subaru          1
# Toyota          5

# %%
pd.crosstab(a['Manufacturer'],a['Vehicle_type'])
# Out:
# Vehicle_type  Car
# Manufacturer
# Cadillac        1
# Chrysler        1
# Dodge           6
# Ford            5
# Honda           3
# Jeep            3
# Lexus           2
# Lincoln         1
# Mercedes-B      1
# Mercury         2
# Mitsubishi      2
# Nissan          4
# Oldsmobile      2
# Plymouth        1
# Pontiac         1
# Subaru          1
# Toyota          5

# %%
a
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales_in_thousands, four_year_resale_value, Vehicle_type, Price_in_thousands, Engine_size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel_capacity, Fuel_efficiency]
# Index: []

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0          Acura  Integra              16.919                  16.360
# 1          Acura       TL              39.384                  19.875
# 2          Acura       CL              14.114                  18.225
# 3          Acura       RL               8.588                  29.725
# 4           Audi       A4              20.397                  22.255
# ..           ...      ...                 ...                     ...
# 152        Volvo      V40               3.545                     NaN
# 153        Volvo      S70              15.245                     NaN
# 154        Volvo      V70              17.531                     NaN
# 155        Volvo      C70               3.493                     NaN
# 156        Volvo      S80              18.969                     NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
a=data[data["Vehicle_type"]=="Passenger"]
#pd.crosstab(a['Manufacturer'],a["Vehicle_type"])

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0          Acura  Integra              16.919                  16.360
# 1          Acura       TL              39.384                  19.875
# 2          Acura       CL              14.114                  18.225
# 3          Acura       RL               8.588                  29.725
# 4           Audi       A4              20.397                  22.255
# ..           ...      ...                 ...                     ...
# 152        Volvo      V40               3.545                     NaN
# 153        Volvo      S70              15.245                     NaN
# 154        Volvo      V70              17.531                     NaN
# 155        Volvo      C70               3.493                     NaN
# 156        Volvo      S80              18.969                     NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
a
# Out:
#     Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0          Acura  Integra              16.919                  16.360
# 1          Acura       TL              39.384                  19.875
# 2          Acura       CL              14.114                  18.225
# 3          Acura       RL               8.588                  29.725
# 4           Audi       A4              20.397                  22.255
# ..           ...      ...                 ...                     ...
# 152        Volvo      V40               3.545                     NaN
# 153        Volvo      S70              15.245                     NaN
# 154        Volvo      V70              17.531                     NaN
# 155        Volvo      C70               3.493                     NaN
# 156        Volvo      S80              18.969                     NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
pd.crosstab(a['Manufacturer'],a['Vehicle_type'])
# Out:
# Vehicle_type  Passenger
# Manufacturer
# Acura                 4
# Audi                  3
# BMW                   3
# Buick                 4
# Cadillac              4
# Chevrolet             9
# Chrysler              6
# Dodge                 5
# Ford                  6
# Honda                 2
# Hyundai               3
# Infiniti              1
# Jaguar                1
# Lexus                 4
# Lincoln               2
# Mercedes-B            8
# Mercury               4
# Mitsubishi            5
# Nissan                3
# Oldsmobile            4
# Plymouth              3
# Pontiac               5
# Porsche               3
# Saab                  2
# Saturn                5
# Subaru                1
# Toyota                4
# Volkswagen            6
# Volvo                 6

# %% [markdown]
# ## Groupby Bivariant

# %%
passenger=data[data['Vehicle_type']=='Passenger']
car=data[data['Vehicle_type']=='Car']

# %%
data.groupby(['Manufacturer']).agg({'Sales_in_thousands':['max','min','mean','std']})
# Out:
#              Sales_in_thousands
#                             max     min        mean         std
# Manufacturer
# Acura                    39.384   8.588   19.751250   13.538381
# Audi                     20.397   1.380   13.519000   10.543726
# BMW                      19.747   9.231   15.501667    5.542837
# Buick                    91.561  27.851   60.504750   31.601405
# Cadillac                 63.729   6.536   22.435600   23.373081
# Chevrolet               145.519  17.947   61.596111   52.335200
# Chrysler                 53.480   7.854   28.817286   14.834026
# Dodge                   227.061   0.916   82.740818   71.975789
# Ford                    540.561  35.068  183.875909  141.373938
# Honda                   230.902  12.855  118.534800   92.522535
# Hyundai                  66.692  29.450   45.775333   19.040796
# Infiniti                 23.713  23.713   23.713000         NaN
# Jaguar                   15.467  15.467   15.467000         NaN
# ...

# %%
data.groupby(['Vehicle_type']).agg({'Price_in_thousands':['max','min','mean','std']})
# Out:
#              Price_in_thousands
#                             max     min       mean        std
# Vehicle_type
# Car                      60.105  11.528  26.319975  10.169436
# Passenger                85.500   9.235  27.763200  15.566574

# %%
data.groupby(['Vehicle_type']).agg({'Sales_in_thousands':['max','min','mean','std']})
# Out:
#              Sales_in_thousands
#                             max    min       mean        std
# Vehicle_type
# Car                     540.561  9.126  80.622293  98.192626
# Passenger               247.994  0.110  43.234345  50.557875

# %%
data.groupby(['Vehicle_type']).agg({'Price_in_thousands':['max','min','mean','std']}).plot(kind='bar')
# Out:
# <Axes: xlabel='Vehicle_type'>
